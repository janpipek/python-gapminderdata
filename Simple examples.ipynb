# %% [markdown]
# # Simple example using the gapminderdata library
#
# Visualizations using `plotly.express` that actually contains a limited subset of the full data too.

# %%
import plotly.express as px
from gapminderdata import read_columns, read_countries

# %%
data = (
    read_columns(["total_population_with_projections", "hdi_human_development_index", "energy_use_per_person"])
    .dropna()
    .merge(read_countries(), left_on="geo", right_index=True)
    .reset_index()
    .sort_values("time")
)

# %%
fig = px.line(
    data[data.name.isin(['Czech Republic', 'Sweden', 'Austria', 'Bulgaria', 'Hungary', 'Portugal', 'Cuba', 'Greece'])],
    color="name",
    x="time",
    y="total_population_with_projections",
)
fig.show()
# Out:
# <div>
#
#
#             <div id="47decbe6-d3d2-4306-a267-999c96d644bc" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("47decbe6-d3d2-4306-a267-999c96d644bc")) {
#                     Plotly.newPlot(
#                         '47decbe6-d3d2-4306-a267-999c96d644bc',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "name=Portugal<br>time=%{x}<br>total_population_with_projections=%{y}", "legendgroup": "name=Portugal", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "name=Portugal", "showlegend": true, "type": "scatter", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013], "xaxis": "x", "y": [9925000.0, 9946000.0, 9982000.0, 10030000.0, 10080000.0, 10120000.0, 10170000.0, 10210000.0, 10250000.0, 10290000.0, 10340000.0, 10380000.0, 10420000.0, 10470000.0, 10510000.0, 10540000.0, 10580000.0, 10610000.0, 10630000.0, 10660000.0, 10680000.0, 10690000.0, 10700000.0, 10700000.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=Austria<br>time=%{x}<br>total_population_with_projections=%{y}", "legendgroup": "name=Austria", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "name=Austria", "showlegend": true, "type": "scatter", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013], "xaxis": "x", "y": [7671000.0, 7720000.0, 7778000.0, 7840000.0, 7894000.0, 7936000.0, 7960000.0, 7972000.0, 7976000.0, 7985000.0, 8005000.0, 8038000.0, 8083000.0, 8134000.0, 8186000.0, 8232000.0, 8273000.0, 8310000.0, 8342000.0, 8370000.0, 8394000.0, 8413000.0, 8429000.0, 8441000.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=Czech Republic<br>time=%{x}<br>total_population_with_projections=%{y}", "legendgroup": "name=Czech Republic", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "name=Czech Republic", "showlegend": true, "type": "scatter", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013], "xaxis": "x", "y": [10300000.0, 10310000.0, 10310000.0, 10320000.0, 10320000.0, 10320000.0, 10310000.0, 10300000.0, 10280000.0, 10260000.0, 10240000.0, 10230000.0, 10210000.0, 10200000.0, 10200000.0, 10220000.0, 10260000.0, 10310000.0, 10380000.0, 10440000.0, 10490000.0, 10530000.0, 10570000.0, 10590000.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=Cuba<br>time=%{x}<br>total_population_with_projections=%{y}", "legendgroup": "name=Cuba", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "name=Cuba", "showlegend": true, "type": "scatter", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013], "xaxis": "x", "y": [10570000.0, 10650000.0, 10730000.0, 10790000.0, 10850000.0, 10900000.0, 10950000.0, 10990000.0, 11030000.0, 11070000.0, 11100000.0, 11140000.0, 11180000.0, 11210000.0, 11230000.0, 11250000.0, 11270000.0, 11270000.0, 11270000.0, 11260000.0, 11260000.0, 11250000.0, 11250000.0, 11240000.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=Sweden<br>time=%{x}<br>total_population_with_projections=%{y}", "legendgroup": "name=Sweden", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "name=Sweden", "showlegend": true, "type": "scatter", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013], "xaxis": "x", "y": [8559000.0, 8617000.0, 8679000.0, 8739000.0, 8790000.0, 8827000.0, 8847000.0, 8854000.0, 8853000.0, 8852000.0, 8860000.0, 8877000.0, 8902000.0, 8935000.0, 8978000.0, 9029000.0, 9091000.0, 9161000.0, 9237000.0, 9311000.0, 9380000.0, 9441000.0, 9495000.0, 9546000.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=Bulgaria<br>time=%{x}<br>total_population_with_projections=%{y}", "legendgroup": "name=Bulgaria", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "name=Bulgar ...
#                         {"height": 600, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#

# %%
fig = px.scatter(
    data,
    animation_frame="time",
    x="energy_use_per_person",
    y="hdi_human_development_index",
    hover_name="name",
    color="world_6region",
    size="total_population_with_projections")
fig.show()
# Out:
# <div>
#
#
#             <div id="b3c74fe3-a98e-4063-bacd-68ae4e871035" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b3c74fe3-a98e-4063-bacd-68ae4e871035")) {
#                     Plotly.newPlot(
#                         'b3c74fe3-a98e-4063-bacd-68ae4e871035',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>world_6region=america<br>time=1990<br>energy_use_per_person=%{x}<br>hdi_human_development_index=%{y}<br>total_population_with_projections=%{marker.size}", "hovertext": ["Guyana", "Trinidad and Tobago", "Colombia", "Nicaragua", "Paraguay", "Jamaica", "United States", "Uruguay", "Chile", "Bolivia", "Brazil", "Belize", "Barbados", "Mexico", "El Salvador", "Cuba", "Costa Rica", "Ecuador", "Canada", "Dominican Republic", "Venezuela", "Peru", "Haiti", "Argentina", "Honduras", "Guatemala", "Panama"], "legendgroup": "world_6region=america", "marker": {"color": "#636efa", "size": [724900.0, 1215000.0, 33200000.0, 4121000.0, 4244000.0, 2365000.0, 253300000.0, 3109000.0, 13190000.0, 6658000.0, 149700000.0, 190200.0, 259500.0, 84310000.0, 5333000.0, 10570000.0, 3070000.0, 10260000.0, 27700000.0, 7195000.0, 19690000.0, 21690000.0, 7125000.0, 32640000.0, 4889000.0, 8923000.0, 2416000.0], "sizemode": "area", "sizeref": 3397500.0, "symbol": "circle"}, "mode": "markers", "name": "world_6region=america", "showlegend": true, "type": "scatter", "x": [514.0337099999999, 4900.00655, 706.78433, 487.16765, 729.2193, 1148.6571900000001, 7671.77307, 723.84597, 1057.93803, 380.7611, 938.76755, 566.3389400000001, 1236.63776, 1448.96836, 469.78468, 1645.06414, 541.8074, 619.49223, 7602.67493, 558.88464, 1993.1329999999998, 445.98055, 219.79308999999998, 1407.38675, 480.20535, 476.1671, 603.34786], "xaxis": "x", "y": [0.541, 0.67, 0.5920000000000001, 0.495, 0.58, 0.6509999999999999, 0.86, 0.6920000000000001, 0.7, 0.535, 0.611, 0.648, 0.7140000000000001, 0.648, 0.529, 0.6759999999999999, 0.653, 0.643, 0.8490000000000001, 0.596, 0.634, 0.613, 0.408, 0.705, 0.507, 0.478, 0.662], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>world_6region=middle_east_north_africa<br>time=1990<br>energy_use_per_person=%{x}<br>hdi_human_development_index=%{y}<br>total_population_with_projections=%{marker.size}", "hovertext": ["Tunisia", "Jordan", "Iran", "Iraq", "Israel", "Egypt", "Kuwait", "Morocco", "Qatar", "Syria", "Libya", "Bahrain", "Algeria", "Saudi Arabia", "United Arab Emirates", "Yemen"], "legendgroup": "world_6region=middle_east_north_africa", "marker": {"color": "#EF553B", "size": [8215000.0, 3416000.0, 54870000.0, 17370000.0, 4500000.0, 56840000.0, 2088000.0, 24780000.0, 473700.0, 12320000.0, 4334000.0, 492900.0, 25300000.0, 16140000.0, 1809000.0, 11950000.0], "sizemode": "area", "sizeref": 3397500.0, "symbol": "circle"}, "mode": "markers", "name": "world_6region=middle_east_north_africa", "showlegend": true, "type": "scatter", "x": [600.8810900000001, 919.5016400000001, 1233.0370599999999, 1147.36764, 2460.46545, 561.74281, 4338.50873, 306.21936, 13698.286269999999, 840.84551, 2517.10194, 10555.27079, 856.1588800000001, 3552.71429, 10979.65405, 208.46278999999998], "xaxis": "x", "y": [0.569, 0.62, 0.5720000000000001, 0.5720000000000001, 0.785, 0.547, 0.713, 0.45799999999999996, 0.754, 0.556, 0.6809999999999999, 0.745, 0.5770000000000001, 0.698, 0.726, 0.405], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>world_6region=europe_central_asia<br>time=1990<br>energy_use_per_person=%{x}<br>hdi_human_development_index=%{y}<br>total_population_with_projections=%{marker.size}", "hovertext": ["Belgium", "Portugal", "Estonia", "Kazakhstan", "Netherlands", "Tajikistan", "Spain", "Switzerland", "Kyrgyz Republic", "Finland", "Turkey", "Iceland", "Norway", "Ukraine", "Austria", "Poland", "France", "Italy", "United Kingdom", "Denmark", "Moldova", "Germany", "Russia", "Malta", "Czech Republic", "Cyprus", "Serbia", "Sweden", "Slovenia", "Lithuania", "Slovak Republic", "Luxembourg", "Romania", "Latvia", "Bulgaria", "Armenia", "Ireland", "Croatia", "Albania", "Hungary", "Greece"], "legendgroup": "world_6region=europe_central_asia", "marker": {"color": "#00cc96", "size": [9949000.0, 9925000 ...

# %%
fig = px.choropleth(
    data,
    locations="iso3166_1_alpha3",
    color="energy_use_per_person",
    hover_name="name",
    animation_frame="time",
    projection="orthographic"
)
fig.show()
# Out:
# <div>
#
#
#             <div id="a8baead3-e052-454d-8e51-a4c1bf2175fb" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a8baead3-e052-454d-8e51-a4c1bf2175fb")) {
#                     Plotly.newPlot(
#                         'a8baead3-e052-454d-8e51-a4c1bf2175fb',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>time=1990<br>iso3166_1_alpha3=%{location}<br>energy_use_per_person=%{z}", "hovertext": ["Guyana", "Tunisia", "Jordan", "Belgium", "Portugal", "Japan", "Trinidad and Tobago", "Colombia", "Estonia", "Kazakhstan", "Netherlands", "Benin", "Nicaragua", "Tajikistan", "Spain", "Thailand", "Bangladesh", "Switzerland", "Kyrgyz Republic", "Paraguay", "South Korea", "Kenya", "Jamaica", "Finland", "Turkey", "Iran", "Hong Kong, China", "United States", "Nepal", "Philippines", "Iraq", "Australia", "Uruguay", "Gabon", "Iceland", "Norway", "Congo, Rep.", "Ukraine", "Austria", "Poland", "France", "Israel", "Fiji", "Tanzania", "Italy", "Chile", "Togo", "United Kingdom", "Egypt", "Kuwait", "Denmark", "Morocco", "Bolivia", "Moldova", "Singapore", "Botswana", "Mozambique", "Senegal", "Brazil", "Belize", "Germany", "Russia", "Malta", "Sudan", "Czech Republic", "Mongolia", "Cyprus", "Barbados", "Myanmar", "Brunei", "Mexico", "El Salvador", "Cuba", "Serbia", "Malaysia", "Costa Rica", "Qatar", "Syria", "Swaziland", "Ecuador", "Libya", "Bahrain", "Sri Lanka", "Sweden", "Canada", "Algeria", "Slovenia", "Lithuania", "Slovak Republic", "Sao Tome and Principe", "Mauritius", "Dominican Republic", "Luxembourg", "Romania", "Latvia", "Bulgaria", "Venezuela", "Tonga", "Saudi Arabia", "Armenia", "Ireland", "Congo, Dem. Rep.", "Croatia", "India", "Vietnam", "Zambia", "Peru", "Cote d'Ivoire", "Albania", "United Arab Emirates", "Haiti", "Ghana", "South Africa", "Gambia", "Hungary", "New Zealand", "Yemen", "Samoa", "Argentina", "Greece", "Honduras", "Indonesia", "Guatemala", "Cameroon", "China", "Pakistan", "Zimbabwe", "Panama"], "locations": ["GUY", "TUN", "JOR", "BEL", "PRT", "JPN", "TTO", "COL", "EST", "KAZ", "NLD", "BEN", "NIC", "TJK", "ESP", "THA", "BGD", "CHE", "KGZ", "PRY", "KOR", "KEN", "JAM", "FIN", "TUR", "IRN", "HKG", "USA", "NPL", "PHL", "IRQ", "AUS", "URY", "GAB", "ISL", "NOR", "COG", "UKR", "AUT", "POL", "FRA", "ISR", "FJI", "TZA", "ITA", "CHL", "TGO", "GBR", "EGY", "KWT", "DNK", "MAR", "BOL", "MDA", "SGP", "BWA", "MOZ", "SEN", "BRA", "BLZ", "DEU", "RUS", "MLT", "SDN", "CZE", "MNG", "CYP", "BRB", "MMR", "BRN", "MEX", "SLV", "CUB", "SRB", "MYS", "CRI", "QAT", "SYR", "SWZ", "ECU", "LBY", "BHR", "LKA", "SWE", "CAN", "DZA", "SVN", "LTU", "SVK", "STP", "MUS", "DOM", "LUX", "ROU", "LVA", "BGR", "VEN", "TON", "SAU", "ARM", "IRL", "COD", "HRV", "IND", "VNM", "ZMB", "PER", "CIV", "ALB", "ARE", "HTI", "GHA", "ZAF", "GMB", "HUN", "NZL", "YEM", "WSM", "ARG", "GRC", "HND", "IDN", "GTM", "CMR", "CHN", "PAK", "ZWE", "PAN"], "name": "", "type": "choropleth", "z": [514.0337099999999, 600.8810900000001, 919.5016400000001, 4809.867270000001, 1680.96239, 3551.16177, 4900.00655, 706.78433, 6232.732, 4492.85307, 4394.54209, 333.69817, 487.16765, 1004.5464099999999, 2317.4767699999998, 741.28271, 119.95458, 3627.69281, 1704.81463, 729.2193, 2167.33961, 457.72522999999995, 1148.6571900000001, 5691.57119, 977.6642400000001, 1233.0370599999999, 1510.63389, 7671.77307, 308.76541000000003, 463.44304000000005, 1147.36764, 5061.50846, 723.84597, 1240.69535, 8907.79198, 4966.89358, 322.59901, 4856.58585, 3240.1113600000003, 2705.6087399999997, 3828.4092600000004, 2460.46545, 392.25256, 382.29888, 2583.88808, 1057.93803, 333.57802999999996, 3597.05162, 561.74281, 4338.50873, 3376.7833100000003, 306.21936, 380.7611, 2676.53869, 3782.7202799999995, 884.1587900000001, 447.02497999999997, 223.19766, 938.76755, 566.3389400000001, 4421.36453, 5928.660989999999, 1961.64271, 412.45549, 4796.94146, 1560.47973, 1780.7032, 1236.63776, 262.86972000000003, 6673.06065, 1448.96836, 469.78468, 1645.06414, 2598.79304, 1210.3968, 541.8074, 13698.286269999999, 840.84551, 358.49594, 619.49223, 2517.10194, 10555.27079, 318.30775, 5514.55753, 7602.67493, 856.1588800000001, 2857.56453, 4344.172729999999, 4024.6690700000004, 205.94447, 629.38207, 558.88464, 8874.105 ...
#                         {"coloraxis": {"colorbar": {"title": {"text": "energy_use_per_person"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 0.98], "y": [0.0, 1.0]}, "projection": {"type": "orthographic"}}, "height": 600, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "sliders": [{"active": 0, "currentvalue": {"prefix": "time="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["1990"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1990", "method": "animate"}, {"args": [["1991"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1991", "method": "animate"}, {"args": [["1992"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1992", "method": "animate"}, {"args": [["1993"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1993", "method": "animate"}, {"args": [["1994"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1994", "method": "animate"}, {"args": [["1995"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1995", "method": "animate"}, {"args": [["1996"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1996", "method": "animate"}, {"args": [["1997"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1997", "method": "animate"}, {"args": [["1998"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1998", "method": "animate"}, {"args": [["1999"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1999", "method": "animate"}, {"args": [["2000"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2000", "method": "animate"}, {"args": [["2001"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"dur
